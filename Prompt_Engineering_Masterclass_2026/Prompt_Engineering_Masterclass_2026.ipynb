# %%
from google.colab import ai

# %% [markdown]
# # **MODULE 1 — Foundations**

# %% [markdown]
# 1. Simple Prompt

# %%
simple_prompt = """
Explain photosynthesis in one sentence.
"""

output = ai.generate_text(simple_prompt)
print("=== Simple Prompt ===")
print(output)

# %% [markdown]
# 2. Good vs Bad Prompt

# %%
quality_prompt = """
Rewrite this bad prompt into a good one:
Bad: Tell me about space.
"""

output = ai.generate_text(quality_prompt)
print("=== Good vs Bad Prompt ===")
print(output)

# %% [markdown]
# # **MODULE 2 — Token Efficiency**

# %% [markdown]
# 3. Compression Prompting

# %%
compression_prompt = """
Explain quantum computing in exactly 3 sentences.
"""

output = ai.generate_text(compression_prompt)
print("=== Compression Prompt ===")
print(output)

# %% [markdown]
# 4. Structured Output

# %%
structured_prompt = """
Explain gravity using:
- 1 definition
- 2 bullet points
- 1 example
"""

output = ai.generate_text(structured_prompt)
print("=== Structured Output ===")
print(output)

# %% [markdown]
# 5. Keyword Prompting

# %%
keyword_prompt = """
Give 5 keywords describing climate change.
"""

output = ai.generate_text(keyword_prompt)
print("=== Keyword Prompt ===")
print(output)

# %% [markdown]
# 6. Minimal Context

# %%
minimal_context_prompt = """
Summarize the following text in 20 words:
Plants convert sunlight into energy through photosynthesis.
"""

output = ai.generate_text(minimal_context_prompt)
print("=== Minimal Context ===")
print(output)

# %% [markdown]
# 7. Reuse Output (Chaining)

# %%
chaining_prompt = """
Step 1: Summarize AI in one sentence.
Step 2: Expand that summary into a paragraph.
"""

output = ai.generate_text(chaining_prompt)
print("=== Chaining Prompt ===")
print(output)

# %% [markdown]
# # MODULE 3 — Output **Quality**

# %% [markdown]
# 8. Step-by-Step Reasoning

# %%
reasoning_prompt = """
Think step-by-step.
Why do seasons change?
"""

output = ai.generate_text(reasoning_prompt)
print("=== Step-by-Step Reasoning ===")
print(output)

# %% [markdown]
# 9. Self-Correction Loop

# %%
self_correct_prompt = """
Explain the Big Bang.
Then critique your explanation.
Then improve it.
"""

output = ai.generate_text(self_correct_prompt)
print("=== Self-Correction Loop ===")
print(output)

# %% [markdown]
# 10. Meta-Prompting

# %%
meta_prompt = """
Describe your plan in 3 steps.
Then execute the plan.
Question: Why do volcanoes erupt?
"""

output = ai.generate_text(meta_prompt)
print("=== Meta Prompt ===")
print(output)

# %% [markdown]
# 11. Constraint Prompting

# %%
constraint_prompt = """
Explain gravity using:
- Simple language
- No metaphors
- Max 5 sentences
"""

output = ai.generate_text(constraint_prompt)
print("=== Constraint Prompt ===")
print(output)

# %% [markdown]
# 12. Framework Prompting

# %%
framework_prompt = """
Use the structure:
Problem → Cause → Solution
Topic: Air pollution
"""

output = ai.generate_text(framework_prompt)
print("=== Framework Prompt ===")
print(output)

# %% [markdown]
# # MODULE 4 — Control & **Reliability**

# %% [markdown]
# 13. Delimiter Prompting

# %%
delimiter_prompt = """
Summarize the text between ###.
###Gravity pulls objects together due to mass.###
"""

output = ai.generate_text(delimiter_prompt)
print("=== Delimiter Prompt ===")
print(output)

# %% [markdown]
# 14. Role Prompting

# %%
role_prompt = """
Act as a cybersecurity expert.
Explain phishing.
"""

output = ai.generate_text(role_prompt)
print("=== Role Prompt ===")
print(output)

# %% [markdown]
# 15. JSON Output

# %%
json_prompt = """
Return output in valid JSON:
{
  "concept": "",
  "example": ""
}
Topic: Photosynthesis
"""

output = ai.generate_text(json_prompt)
print("=== JSON Prompt ===")
print(output)

# %% [markdown]
# 16. Error Checking

# %%
error_check_prompt = """
Generate 3 facts about the Moon.
Verify each fact as true or false.
"""

output = ai.generate_text(error_check_prompt)
print("=== Error Checking ===")
print(output)

# %% [markdown]
# 17. Branching Logic

# %%
branch_prompt = """
If topic is science → explain simply.
If topic is history → give a timeline.
Topic: Gravity
"""

output = ai.generate_text(branch_prompt)
print("=== Branching Prompt ===")
print(output)

# %% [markdown]
# # MODULE 5 — Iterative **Improvement**

# %% [markdown]
# 18. Iterative Refinement

# %%
refine_prompt = """
Write a paragraph about AI.
Rewrite it simpler.
Rewrite it more formal.
Rewrite it more creative.
"""

output = ai.generate_text(refine_prompt)
print("=== Iterative Refinement ===")
print(output)

# %% [markdown]
# 19. Prompt Chaining

# %%
chain_prompt = """
1. Define renewable energy.
2. Give 3 examples.
3. Explain why it matters.
"""

output = ai.generate_text(chain_prompt)
print("=== Prompt Chaining ===")
print(output)

# %% [markdown]
# 20. Pipeline Prompting

# %%
pipeline_prompt = """
Pipeline:
1. Extract keywords from text.
2. Explain each keyword.
3. Create a study guide.

Text: Photosynthesis is the process by which plants convert sunlight into energy.
"""

output = ai.generate_text(pipeline_prompt)
print("=== Pipeline Prompt ===")
print(output)

# %% [markdown]
# 21. Knowledge Distillation

# %%
distill_prompt = """
Explain quantum entanglement in one simple analogy.
"""

output = ai.generate_text(distill_prompt)
print("=== Knowledge Distillation ===")
print(output)

# %% [markdown]
# # MODULE 6 — Advanced **Engineering**

# %% [markdown]
# 22. Simulation Prompting

# %%
simulation_prompt = """
Simulate a conversation between a student and a physics teacher about gravity.
"""

output = ai.generate_text(simulation_prompt)
print("=== Simulation Prompt ===")
print(output)

# %% [markdown]
# 23. Hypothesis Prompting

# %%
hypothesis_prompt = """
Give 3 hypotheses about why dinosaurs went extinct.
"""

output = ai.generate_text(hypothesis_prompt)
print("=== Hypothesis Prompt ===")
print(output)

# %% [markdown]
# 24. Decision Prompting

# %%
decision_prompt = """
Choose the best renewable energy source for a small island.
Explain your reasoning.
"""

output = ai.generate_text(decision_prompt)
print("=== Decision Prompt ===")
print(output)

# %% [markdown]
# 25. Parameterized Prompting

# %%
topic = "volcanoes"
level = "beginner"

param_prompt = f"Explain {topic} to a {level}."

output = ai.generate_text(param_prompt)
print("=== Parameterized Prompt ===")
print(output)

# %% [markdown]
# # MODULE 7 — **Debugging**

# %% [markdown]
# 26. Error-Finding Prompt

# %%
debug_prompt = """
Find scientific errors in this text:
Gravity makes objects float upward.
"""

output = ai.generate_text(debug_prompt)
print("=== Debug Prompt ===")
print(output)

# %% [markdown]
# 27. Stress Testing

# %%
stress_prompt = """
Test this prompt with edge cases:
Explain gravity.
"""

output = ai.generate_text(stress_prompt)
print("=== Stress Test ===")
print(output)

# %% [markdown]
# # MODULE 8 — **Capstone**

# %% [markdown]
# 28. Capstone Workflow Prompt

# %%
capstone_prompt = """
Build a complete AI workflow:
1. Summarize AI.
2. Extract keywords.
3. Explain each keyword.
4. Create a study guide.
5. Improve the study guide.
"""

output = ai.generate_text(capstone_prompt)
print("=== Capstone Workflow ===")
print(output)

# %% [markdown]
# # **BONUS MODULE**

# %% [markdown]
# 29. Memory Prompting

# %%
memory_prompt = """
Remember the following details and use them later in the conversation:
Name: Alex
Favorite subject: Physics
Goal: Learn about black holes

Now, introduce yourself to Alex and mention their favorite subject and goal.
"""

memory_output = ai.generate_text(memory_prompt)
print("=== Memory Prompting ===")
print(memory_output)

# %% [markdown]
# 30. Guardrail Prompting

# %%
guardrail_prompt = """
Explain how encryption works.
Do NOT provide any instructions for hacking, breaking into systems,
or bypassing security.

Focus only on high-level, ethical explanations.
"""

guardrail_output = ai.generate_text(guardrail_prompt)
print("=== Guardrail Prompting ===")
print(guardrail_output)

# %% [markdown]
# 31. Style Transfer Prompting

# %%
style_transfer_prompt = """
Transform the following paragraph into a poetic style:

'Gravity is a force that pulls objects toward each other due to their mass.'
"""

style_transfer_output = ai.generate_text(style_transfer_prompt)
print("=== Style Transfer Prompting ===")
print(style_transfer_output)

# %% [markdown]
# 32. Multi-Agent Prompting

# %%
multi_agent_prompt = """
Simulate a debate between two AI agents:

Agent 1: Argues that AI will greatly benefit humanity.
Agent 2: Argues that AI poses serious risks.

Each agent should respond in 3 turns.
"""

multi_agent_output = ai.generate_text(multi_agent_prompt)
print("=== Multi-Agent Prompting ===")
print(multi_agent_output)

# %% [markdown]
# 33. Reflection Prompting

# %%
reflection_prompt = """
Answer the question: Why is the sky blue?

Then, in a separate section, reflect on your own reasoning:
- Was the explanation accurate?
- What could be improved?
"""

reflection_output = ai.generate_text(reflection_prompt)
print("=== Reflection Prompting ===")
print(reflection_output)
